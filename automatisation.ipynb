# %%
#imports
import pandas as pd
import numpy as np
import random
from faker import Faker
fake=Faker()
from sqlalchemy import *
from datetime import *
engine = create_engine('mysql://myuser:myuser@localhost/VeloMax')
def Randomfill(lst,size=15):
    ret=[]
    for i in range(size):
        ret.append(random.choice(lst))
    return ret
def Randomuniquefill(lst,size=15):
    return random.sample(lst,size)

# %%
#PIECESDERECHANGE

Size=100
#NumProdPieces=np.random.randint(1,100,size=Size)

NumProdPieces=np.random.choice(np.arange(0,100), size=Size, replace=False)
Description=Randomfill(['Neuf','occasion','comme neuf'],Size)
dateIntroduction=[date(*i) for i in np.random.randint([2019,1,1],[2021,12,28],size=(Size,3))]
#date=datetime.date(*list(dateIntroduction))
dateDiscont=[date(*i) for i in np.random.randint([2022,1,1],[2023,12,28],size=(Size,3))]
PrixUnitaire=np.random.randint(10,300,size=Size)
nbDispo=np.random.randint(4,20,size=Size)
categorie=Randomfill(['cadre','guidon','freins','selle','derailleurAvant','derailleurArriere','roueAvant','roueArriere','reflecteurs','pedalier','ordinateur','panier'],Size)
nbVendu=np.random.randint(0,1000,size=Size)

# list(zip(lst, lst2))
engine.execute("DROP TABLE IF EXISTS piece;")
engine.execute("CREATE TABLE IF NOT EXISTS piece (numProd VARCHAR(10) PRIMARY KEY,description TEXT(1000),dateIntroduction date,dateDiscont date,prixUnitaire INT,nbDispo INT,categorie VARCHAR(40), nbVendu INT );")

piecesdeRechangedf = pd.DataFrame(list(zip(NumProdPieces,categorie,Description,dateIntroduction,dateDiscont,PrixUnitaire,nbDispo, nbVendu)),columns=['NumProd','categorie','description','dateIntroduction','dateDiscont','prixUnitaire','nbDispo','nbVendu'])
print(piecesdeRechangedf)
piecesdeRechangedf.to_sql('piece', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM piece").fetchall()
# Out:
#     NumProd        categorie description dateIntroduction dateDiscont  \
# 0        29      roueArriere    occasion       2019-04-25  2022-10-17
# 1        60            cadre    occasion       2019-01-18  2022-10-24
# 2        90           panier        Neuf       2020-09-22  2022-01-05
# 3        64            selle        Neuf       2020-05-16  2022-05-22
# 4        23            selle  comme neuf       2020-11-12  2022-04-21
# ..      ...              ...         ...              ...         ...
# 95       40           freins  comme neuf       2020-03-18  2022-07-27
# 96        0        roueAvant        Neuf       2020-10-17  2022-05-21
# 97       96         pedalier        Neuf       2019-08-17  2022-01-16
# 98       56  derailleurAvant  comme neuf       2020-01-16  2022-11-15
# 99       11        roueAvant        Neuf       2019-01-03  2022-08-25
#
#     prixUnitaire  nbDispo  nbVendu
# 0             68        8      492
# 1             37       18      216
# ...

# %%
#BICYCLETTES
Size=15
NumProdBicyclettes=np.random.choice(np.arange(100,200), size=Size, replace=False)
fake=Faker()
#Nom=(fake.name())
Nom=[fake.first_name() for i in range(Size)]
Grandeur=Randomfill(['Homme','Femme','Enfant'],Size)
PrixUnitaire=np.random.randint(45,3000,size=Size)
ligneProduit=Randomfill(['VTT','Velo de Course','Classique','BMX'],Size)
nbDispo=np.random.randint(4,20,size=Size)
nbVendu=np.random.randint(0,1000,size=Size)

engine.execute("DROP TABLE IF EXISTS bicyclette;")
engine.execute("CREATE TABLE IF NOT EXISTS bicyclette (numProd VARCHAR(10) PRIMARY KEY NOT NULL,nom VARCHAR(40),grandeur VARCHAR(40),prixUnitaire INT,ligneProduit VARCHAR(40),nbDispo INT,nbVendu INT);")
Bicyclettesdf = pd.DataFrame(list(zip(NumProdBicyclettes,Nom,Grandeur,PrixUnitaire,ligneProduit,nbDispo,nbVendu)),columns=['numProd','nom','grandeur','prixUnitaire','ligneProduit','nbDispo','nbVendu'])
print(Bicyclettesdf)
Bicyclettesdf.to_sql('bicyclette', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM bicyclette").fetchall()
# Out:
#     numProd       nom grandeur  prixUnitaire    ligneProduit  nbDispo  nbVendu
# 0       147     Jamie    Homme          1559             VTT        5      701
# 1       115    Brenda   Enfant          2674  Velo de Course       19      787
# 2       136   Timothy    Femme            87  Velo de Course       17      174
# 3       134  Caroline    Homme           727  Velo de Course        5      103
# 4       101       Joe    Homme           755             BMX       18      841
# 5       122    Brenda    Femme          1814       Classique       11      711
# 6       182     Shawn    Homme          1741             BMX       13      409
# 7       144      Adam    Femme          2389             BMX       15      925
# 8       166   Crystal   Enfant           319  Velo de Course        7      820
# 9       111       Amy   Enfant           439             VTT       12      516
# 10      137   Kristin    Femme           349  Velo de Course        8      964
# ...

# %%
#listeMontagePiecesBicyclette
#NumProdBicyclettes


#test=pd.merge(df['cadre'],customer,on='Product_ID',how='outer')
#df=dfcadre,dfg,dff,dfs,dfdav,dfdar,dfrav,dfrar,dfr,dfped,dfo,dfp
def datafill (l,lst):
    for i in lst:
        l=pd.merge(l,i,on='NumProd',how='outer')
    return l


#
dfc = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='cadre'].iloc[:,0:1].to_numpy()[:,0]
#c=piecesdeRechangedf.iloc[:,1:].values
#print(dfc)
dfg = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='guidon'].iloc[:,0:1].to_numpy()[:,0]
#print(dfg)
dff = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='freins'].iloc[:,0:1].to_numpy()[:,0]
#print(dff)
dfs = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='selle'].iloc[:,0:1].to_numpy()[:,0]
#print(dfs)
dfdav = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='derailleurAvant'].iloc[:,0:1].to_numpy()[:,0]
#print(dfdav)
dfdar = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='derailleurArriere'].iloc[:,0:1].to_numpy()[:,0]
#print(dfdar)
dfrav = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='roueAvant'].iloc[:,0:1].to_numpy()[:,0]
dfrar = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='roueArriere'].iloc[:,0:1].to_numpy()[:,0]
dfr = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='reflecteurs'].iloc[:,0:1].to_numpy()[:,0]
dfp = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='pedalier'].iloc[:,0:1].to_numpy()[:,0]
dfo = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='ordinateur'].iloc[:,0:1].to_numpy()[:,0]
dfp = piecesdeRechangedf[piecesdeRechangedf['categorie'] =='panier'].iloc[:,0:1].to_numpy()[:,0]
#['cadre','guidon','freins','selle','derailleurAvant','derailleurArriere','roueAvant','roueArriere','reflecteurs','pedaliers','ordinateur','panier']
data=[NumProdBicyclettes,dfc,dfg,dff,dfs,dfdav,dfdar,dfrav,dfrar,dfr,dfp,dfo,dfp]
names=['numProd','cadre','guidon','freins','selle','derailleurAvant','derailleurArriere','roueAvant','roueArriere','reflecteurs','pedalier','ordinateur','panier']
#df=pd.DataFrame(list(zip(dfc,dfg,dff,dfs,dfdav,dfdar,dfrav,dfrar,dfr,dfp,dfo,dfp)))
#test=pd.merge(df,dfg,on='NumProd',how='outer')
#df.rename(columns=['NumProd','categorie','description','dateIntroduction','dateDiscont','prixUnitaire','nbDispo'])
#test2=pd.merge(test,dff,on='NumProd',how='outer')
#print((len(dfc),len(dfg),len(dff),len(dfs),len(dfs),len(dfdav),len(dfdar),len(dfrav),len(dfrar),len(dfr)))

listeMontagePiecesBicyclettedf=pd.DataFrame.from_dict(dict(zip(names, data)),orient='index')
listeMontagePiecesBicyclettedf = listeMontagePiecesBicyclettedf.transpose()
#NumProdBicyclettes

print(listeMontagePiecesBicyclettedf)
engine.execute("DROP TABLE IF EXISTS listeMontagePiecesBicyclette;")
engine.execute("CREATE TABLE IF NOT EXISTS listeMontagePiecesBicyclette (     numProd VARCHAR(10) REFERENCES bicyclette (numProd),     cadre VARCHAR(10) REFERENCES piece (numProd),     guidon VARCHAR(10) REFERENCES piece (numProd),     freins VARCHAR(10) REFERENCES piece (numProd),     selle VARCHAR(10) REFERENCES piece (numProd),     derailleurAvant VARCHAR(10) REFERENCES piece (numProd),     derailleurArriere VARCHAR(10) REFERENCES piece (numProd),     roueAvant VARCHAR(10) REFERENCES piece (numProd),     roueArriere VARCHAR(10) REFERENCES piece (numProd),     reflecteurs VARCHAR(10) REFERENCES piece (numProd),     pedalier VARCHAR(10) REFERENCES piece (numProd),     ordinateur VARCHAR(10) REFERENCES piece (numProd),     panier VARCHAR(10) REFERENCES piece (numProd) );")

#listeMontagePiecesBicyclettedf = pd.DataFrame(list(zip(dfc,dfg,dff,dfs,dfdav,dfdar,dfrav,dfrar,dfr,dfp,dfo,dfp)))
#print(df)#,columns=['NumProd','categorie','description','dateIntroduction','dateDiscont','prixUnitaire','nbDispo']
listeMontagePiecesBicyclettedf.to_sql('listeMontagePiecesBicyclette', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM listeMontagePiecesBicyclette").fetchall()
print(listeMontagePiecesBicyclettedf)
# Out:
#     numProd  cadre  guidon  freins  selle  derailleurAvant  derailleurArriere  \
# 0     147.0   60.0    33.0    50.0   64.0             98.0               28.0
# 1     115.0   44.0    17.0    72.0   23.0             45.0               43.0
# 2     136.0    1.0    93.0    32.0   63.0             47.0               49.0
# 3     134.0   37.0    85.0    70.0   22.0             20.0               39.0
# 4     101.0   62.0     NaN    61.0   35.0             78.0               87.0
# 5     122.0   30.0     NaN     7.0   97.0             95.0               25.0
# 6     182.0    NaN     NaN    65.0   55.0             92.0               59.0
# 7     144.0    NaN     NaN    83.0   58.0             16.0               46.0
# 8     166.0    NaN     NaN    40.0   52.0             56.0               69.0
# 9     111.0    NaN     NaN     NaN   67.0              NaN                NaN
# 10    137.0    NaN     NaN     NaN   77.0              NaN                NaN
# ...

# %%
#ADRESSE
Size=100
idAdresse=np.random.choice(np.arange(10000,11000), size=Size, replace=False)
fake=Faker()
#Nom=(fake.name())
rue=[fake.street_address().split(' ')[1] for i in range(Size)]
ville=[ fake.city() for i in range(Size)]
codePostal=[fake.postalcode() for i in range(Size)]
province=[fake.state()  for i in range(Size)]

engine.execute("DROP TABLE IF EXISTS adresse;")
engine.execute("CREATE TABLE IF NOT EXISTS adresse ( idAdresse INT PRIMARY KEY, rue VARCHAR(40), ville VARCHAR(40), codePostal VARCHAR(40), province VARCHAR(40) );")
adressedf=pd.DataFrame(list(zip(idAdresse,rue,ville,codePostal,province)),columns=['idAdresse','rue','ville','codePostal','province'])
print(adressedf)
adressedf.to_sql('adresse', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM adresse").fetchall()
# Out:
#     idAdresse        rue                  ville codePostal       province
# 0       10666      Tyler              West Mark      90591       Michigan
# 1       10973  Stephanie       Lake Ashleyhaven      14343         Oregon
# 2       10938      Brent                Foxberg      93581          Idaho
# 3       10979     Parker            Shannonview      72119      Louisiana
# 4       10673    Sanders               Kingtown      24730         Hawaii
# ..        ...        ...                    ...        ...            ...
# 95      10840     Lawson      West Matthewmouth      21927      Tennessee
# 96      10385  Katherine  South Christopherside      21686        Indiana
# 97      10090    Rowland            South April      02301         Hawaii
# 98      10334       Kirk             Angelafort      62540  New Hampshire
# 99      10269      Bryan             Robinburgh      31961  West Virginia
#
# [100 rows x 5 columns]
# ...

# %%
#BOUTIQUESSPECIALISEES
Size=10
idClientBout=np.random.choice(np.arange(900,950), size=Size, replace=False)
fake=Faker()
nom=[fake.last_name() for i in range(Size)]
prenom=[fake.name() for i in range(Size)]



idAdressesboutiques=random.sample(list(idAdresse),Size)
telephone=[fake.phone_number() for i in range(Size)]
courriel=[fake.company_email() for i in range(Size)]
volumeDAchat=[random.uniform(1.0,50.0) for i in range(Size)]
remise=Randomfill([5,8,10,12],Size)

engine.execute("DROP TABLE IF EXISTS boutiquesSpecialisees;")
engine.execute("CREATE TABLE IF NOT EXISTS boutiquesSpecialisees ( idClient INT PRIMARY KEY, nom VARCHAR(40), prenom VARCHAR(40), idAdresse INT REFERENCES adresse (idAdresse), telephone VARCHAR(30) UNIQUE, courriel VARCHAR(100), volumeDachats FLOAT, remise INT );")
boutiquesSpecialiseesdf=pd.DataFrame(list(zip(idClientBout,nom,prenom,idAdressesboutiques,telephone,courriel,volumeDAchat,remise)),columns=['idClient','nom','prenom','idAdresse','telephone','courriel','volumeDAchats','remise'])
boutiquesSpecialiseesdf.to_sql('boutiquesSpecialisees', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM boutiquesSpecialisees;").fetchall()
print(boutiquesSpecialiseesdf)
# Out:
#    idClient       nom          prenom  idAdresse              telephone  \
# 0       949    Becker  Amber Odonnell      10979           345.407.7511
# 1       946    Bailey       David Ray      10711     (372)987-4144x4894
# 2       909   Goodman   William Evans      10269   001-879-871-3654x654
# 3       932     Davis   Brandy Gordon      10288      809-177-0999x9320
# 4       907      Wise   Sandra Mooney      10227      923-202-0917x8398
# 5       929   Fleming  Jeffery Powell      10864   +1-605-762-8764x3713
# 6       938    Harris   Thomas Peters      10146  +1-320-800-0031x59389
# 7       911  Anderson  Brandon Parker      10445          (782)730-4689
# 8       900      Reed   Steven Nguyen      10220           750-881-1278
# 9       945     Green  Deborah Romero      10673      (991)485-2352x198
#
#                          courriel  volumeDAchats  remise
# 0     smithtyler@arnold-jones.com      19.293898      12
# 1  mcculloughjoseph@hernandez.com      11.785899       5
# ...

# %%
#individu
Size=50
#Filtre=[0 if i in idAdressesfournisseur else 1 for i in rue ]
idAdressesindividu=random.sample(list(idAdresse),Size)
idClientIndiv=np.random.choice(np.arange(925,1000), size=Size, replace=False)

prenomindividu=[fake.name().split()[0] for i in range(Size)]
nomindividu=[fake.name().split()[1] for i in range(Size)]
telephoneindividu=[fake.phone_number() for i in range(Size)]
courrielindividu=[fake.email() for i in range(Size)]
noProgramme=np.random.randint(1,5,size=Size)
dateAdhesion=[date(*i) for i in np.random.randint([2021,1,1],[2022,12,28],size=(Size,3))]#np.random.randint([2021,1,1],[2022,28,12],size=(Size,3))


engine.execute("DROP TABLE IF EXISTS individu;")
engine.execute("CREATE TABLE IF NOT EXISTS individu (idClient INT NOT NULL UNIQUE PRIMARY KEY, nom VARCHAR(40), prenom VARCHAR(40), idAdresse INT REFERENCES adresse (idAdresse), telephone VARCHAR(40) UNIQUE, courriel VARCHAR(100), noProgramme INT REFERENCES programme (noProgramme), dateAdhesionProgrammeFidelio DATETIME );")
individudf = pd.DataFrame(list(zip(idClientIndiv,nomindividu,prenomindividu,idAdressesindividu,telephoneindividu,courrielindividu,noProgramme,dateAdhesion)),columns=["idClient", "nom" , "prenom" , "idAdresse", "telephone", "courriel" , "noProgramme" , "dateAdhesionProgrammeFidelio" ])
#print(individudf)
individudf.to_sql('individu', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM individu;").fetchall()
# Out:
# [(925, 'Henry', 'Shannon', 10766, '975.452.6975x60689', 'nflowers@example.com', 1, datetime.datetime(2021, 6, 19, 0, 0)),
#  (926, 'Brown', 'Kyle', 10146, '001-025-944-2152x2738', 'dgreen@example.net', 2, datetime.datetime(2021, 5, 17, 0, 0)),
#  (929, 'Abbott', 'George', 10511, '6614220670', 'annmaxwell@example.org', 3, datetime.datetime(2021, 1, 1, 0, 0)),
#  (930, 'Thomas', 'Cindy', 10262, '(397)510-9505x03109', 'michellegrant@example.com', 1, datetime.datetime(2021, 1, 27, 0, 0)),
#  (931, 'Morgan', 'Pamela', 10711, '+1-100-209-6798x671', 'alexanderamy@example.com', 4, datetime.datetime(2021, 2, 7, 0, 0)),
#  (933, 'Welch', 'Ellen', 10676, '001-130-035-0368x532', 'ashley79@example.com', 3, datetime.datetime(2021, 9, 19, 0, 0)),
#  (934, 'Alvarez', 'Elizabeth', 10788, '(981)595-2273x32565', 'stephanie94@example.net', 3, datetime.datetime(2021, 10, 16, 0, 0)),
#  (935, 'Gordon', 'Ana', 10848, '9614831404', 'robertsonmichael@example.org', 4, datetime.datetime(2021, 11, 13, 0, 0)),
# ...

# %%
#COMMANDE
#idcommande INT PRIMARY KEY,
#    dateCommande DATETIME,
#    adresseLivraison INT REFERENCES adresse (idAdresse)
Size=20
idcommande=np.random.choice(np.arange(13000,13100), size=Size, replace=False)
dateCommande=np.array([date(*i) for i in np.random.randint([2022,1,1],[2023,12,28],size=(Size,3))])#=np.random.randint([2022,1,1],[2023,28,12],size=(Size,3))
idclient=np.array(list(np.random.choice(idClientBout, size=int(Size/2), replace=False))+list(np.random.choice(idClientIndiv, size=int(Size/2), replace=False)))

idadresseLivraison=random.sample(list(idAdresse),k=Size)
engine.execute("DROP TABLE IF EXISTS commande;")
engine.execute("CREATE TABLE IF NOT EXISTS commande ( idCommande INT PRIMARY KEY, dateCommande dateTIME, idClient INT );")
commandedf=pd.DataFrame(list(zip(idcommande,dateCommande,idclient)),columns=['idCommande','dateCommande','idClient'])
commandedf.to_sql('commande', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM commande").fetchall()
print(commandedf)
# Out:
#     idCommande dateCommande  idClient
# 0        13014   2022-09-15       932
# 1        13024   2022-11-14       938
# 2        13074   2022-08-24       900
# 3        13087   2022-11-22       909
# 4        13042   2022-11-16       949
# 5        13021   2022-09-07       929
# 6        13056   2022-02-18       946
# 7        13067   2022-09-22       907
# 8        13071   2022-02-04       911
# 9        13035   2022-04-23       945
# 10       13008   2022-04-06       993
# 11       13010   2022-03-04       931
# 12       13051   2022-06-26       934
# 13       13077   2022-07-08       968
# 14       13036   2022-09-10       929
# 15       13091   2022-02-05       996
# 16       13053   2022-03-18       972
# 17       13046   2022-04-02       930
# 18       13093   2022-04-03       969
# 19       13081   2022-11-01       935

# %%
#LIGNECOMMANDEVELO
Size=15
NumProdCommandevelo=Randomfill(list(NumProdBicyclettes),Size)
idcommandevelo=Randomfill(list(idcommande),Size)



engine.execute("DROP TABLE IF EXISTS ligneCommandeVelo;")
engine.execute("CREATE TABLE IF NOT EXISTS ligneCommandeVelo ( idCommande INT REFERENCES commmande (idCommande), numProd VARCHAR(10) REFERENCES bicyclette (numProd) );")
ligneCommandeVelodf=pd.DataFrame(list(zip(NumProdCommandevelo,idcommandevelo)),columns=['NumProd','idcommande'])
print(ligneCommandeVelodf)
ligneCommandeVelodf.to_sql('ligneCommandeVelo', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM ligneCommandeVelo").fetchall()
# Out:
#     NumProd  idcommande
# 0       153       13008
# 1       137       13021
# 2       106       13056
# 3       182       13056
# 4       111       13081
# 5       122       13087
# 6       136       13081
# 7       122       13081
# 8       166       13074
# 9       101       13091
# 10      106       13042
# 11      122       13051
# 12      122       13087
# 13      147       13021
# 14      187       13071
# [(13008, '153'),
#  (13021, '137'),
#  (13056, '106'),
#  (13056, '182'),
#  (13081, '111'),
#  (13087, '122'),
#  (13081, '136'),
#  (13081, '122'),
#  (13074, '166'),
#  (13091, '101'),
#  (13042, '106'),
#  (13051, '122'),
#  (13087, '122'),
#  (13021, '147'),
#  (13071, '187')]

# %%
#LIGNECOMMANDEPIECE
Size=15
NumProdCommandePiece=Randomfill(list(NumProdPieces),Size)
idcommandePiece=Randomfill(list(idcommande),Size)



engine.execute("DROP TABLE IF EXISTS ligneCommandePiece;")
engine.execute("CREATE TABLE IF NOT EXISTS ligneCommandePiece ( idCommande INT REFERENCES commmande (idCommande), numProd VARCHAR(10) REFERENCES piece (numProd) );")
ligneCommandePiecedf=pd.DataFrame(list(zip(NumProdCommandePiece,idcommandePiece)),columns=['NumProd','idcommande'])
ligneCommandePiecedf.to_sql('ligneCommandePiece', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM ligneCommandePiece").fetchall()
print(ligneCommandePiecedf)
# Out:
#     NumProd  idcommande
# 0        43       13042
# 1        18       13046
# 2         6       13093
# 3        58       13035
# 4        20       13093
# 5        91       13014
# 6         0       13087
# 7        26       13035
# 8        23       13093
# 9        38       13077
# 10       57       13021
# 11       53       13093
# 12       60       13021
# 13       63       13036
# 14       91       13077

# %%
#ListePieceFournisseur

Size=40
Siret=np.random.randint(600000,600200,size=Size)
NumProdPiecesFournisseur=np.random.randint(1,100,size=Size)
PrixFournisseur=np.random.randint(5,200,size=Size)
delaiDeLivraison=Randomfill(['6 semaines','5 semaines','4 semaines','3 semaines','2 semaines','1 semaine','2 jours'],Size)

engine.execute("DROP TABLE IF EXISTS ListePieceFournisseur;")
engine.execute("CREATE TABLE IF NOT EXISTS listePieceFournisseur ( siret VARCHAR(40) REFERENCES fournisseur (siret), numProd VARCHAR(10) REFERENCES piece (numProd), prix FLOAT, delaiDeLivraison dateTIME );")
ListePieceFournisseurdf=pd.DataFrame(list(zip(Siret,NumProdPiecesFournisseur,PrixFournisseur,delaiDeLivraison)),columns=['Siret','NumProd','Prix','delaiDeLivraison'])
ListePieceFournisseurdf.to_sql('ListePieceFournisseur', con=engine,if_exists='append')
engine.execute("SELECT * FROM ListePieceFournisseur").fetchall()
#print(ListePieceFournisseurdf)
# Out:
# [(0, 600053, 78, 18, '3 semaines'),
#  (1, 600074, 42, 144, '6 semaines'),
#  (2, 600176, 96, 182, '2 jours'),
#  (3, 600054, 72, 164, '6 semaines'),
#  (4, 600114, 93, 61, '6 semaines'),
#  (5, 600050, 84, 131, '2 jours'),
#  (6, 600056, 38, 182, '2 jours'),
#  (7, 600163, 67, 45, '2 semaines'),
#  (8, 600101, 50, 133, '2 jours'),
#  (9, 600030, 92, 69, '2 semaines'),
#  (10, 600024, 70, 34, '6 semaines'),
#  (11, 600138, 2, 62, '5 semaines'),
#  (12, 600178, 10, 169, '5 semaines'),
#  (13, 600005, 91, 180, '2 semaines'),
#  (14, 600053, 36, 42, '4 semaines'),
#  (15, 600147, 25, 168, '5 semaines'),
#  (16, 600015, 72, 60, '5 semaines'),
#  (17, 600030, 5, 70, '4 semaines'),
#  (18, 600079, 38, 67, '2 semaines'),
#  (19, 600060, 30, 10, '2 jours'),
#  (20, 600024, 28, 53, '2 semaines'),
#  (21, 600157, 23, 114, '2 jours'),
#  (22, 600034, 60, 182, '2 semaines'),
#  (23, 600151, 80, 163, '1 semaine'),
#  (24, 600192, 19, 92, '2 jours'),
#  (25, 600019, 21, 90, '2 semaines'),
# ...

# %%
#COMMANDEFOURNISSEURS
Size=10

idcommandeFournisseur=np.random.choice(np.arange(13500,13600), size=Size, replace=False)#np.random.randint(13500,14000,size=Size)
dateCommande=np.array([date(*i) for i in np.random.randint([2022,1,1],[2023,12,28],size=(Size,3))])#=np.random.randint([2022,1,1],[2023,28,12],size=(Size,3))

engine.execute("DROP TABLE IF EXISTS commandeFournisseur;")
engine.execute("CREATE TABLE IF NOT EXISTS commandeFournisseur ( idCommande INT PRIMARY KEY, dateCommande dateTIME );")
commandeFournisseurdf=pd.DataFrame(list(zip(idcommandeFournisseur,dateCommande)),columns=['idcommande','dateCommande'])
commandeFournisseurdf.to_sql('commandeFournisseur', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM commandeFournisseur").fetchall()
print(commandeFournisseurdf)
# Out:
#    idcommande dateCommande
# 0       13528   2022-06-23
# 1       13536   2022-07-16
# 2       13551   2022-09-11
# 3       13563   2022-04-16
# 4       13543   2022-02-03
# 5       13522   2022-04-20
# 6       13534   2022-04-27
# 7       13507   2022-09-03
# 8       13575   2022-05-03
# 9       13519   2022-06-10

# %%
#LIGNECOMMANDEPIECEFOURNISSEUR
Size=5
idcommandePieceFournisseur=Randomfill(idcommandeFournisseur,Size)
NumProdCommandePieceFournisseur=Randomfill(NumProdPiecesFournisseur,Size)
numProd=Randomfill(NumProdPieces,Size)
engine.execute("DROP TABLE IF EXISTS ligneCommandePieceFournisseur;")
engine.execute("CREATE TABLE IF NOT EXISTS ligneCommandePieceFournisseur ( idCommande INT REFERENCES commandeFournisseur (idCommande), numProd VARCHAR(10) REFERENCES listePieceFournisseur (numProd) );")
ligneCommandePieceFournisseurdf=pd.DataFrame(list(zip(idcommandePieceFournisseur,NumProdCommandePieceFournisseur)),columns=['idCommande','numProd'])
ligneCommandePieceFournisseurdf.to_sql('ligneCommandePieceFournisseur', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM ligneCommandePieceFournisseur").fetchall()
print(ligneCommandePieceFournisseurdf)
# Out:
#    idCommande  numProd
# 0       13522       51
# 1       13507       30
# 2       13528       72
# 3       13543       91
# 4       13528       31

# %%
#fournisseurs
Size=7
siret=np.random.choice(Siret,size=Size,replace=False)
Filtre=[0 if i in idAdressesboutiques else 1 for i in rue ]
idAdressesfournisseur=random.sample(list(idAdresse),Size,counts=Filtre)
telephonefournisseur=[fake.phone_number() for i in range(Size)]
courrielFournisseur=[fake.email() for i in range(Size)]
nomContactFournisseur=[fake.name() for i in range(Size)]
Qualite=Randomfill([1,2,3,4],15)

engine.execute("DROP TABLE IF EXISTS fournisseur;")
engine.execute("CREATE TABLE IF NOT EXISTS fournisseur ( siret VARCHAR(40) NOT NULL PRIMARY KEY, idAdresse INT REFERENCES adresse (idAdresse), telephone VARCHAR(40), courriel VARCHAR(40), nomContact VARCHAR(40), qualite INT );")
fournisseursdf = pd.DataFrame(list(zip(siret,idAdressesfournisseur,telephonefournisseur,courrielFournisseur,nomContactFournisseur,Qualite)),columns=['siret','idAdresse','telephone','courriel','nomContact','qualite'])
print(fournisseursdf)
fournisseursdf.to_sql('fournisseur', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM fournisseur").fetchall()
# Out:
#     siret  idAdresse              telephone                   courriel  \
# 0  600138      10323       565-617-7054x716      jessica44@example.com
# 1  600101      10579        +1-158-198-2052         eric95@example.org
# 2  600147      10466          (180)936-3185     aprilsmith@example.com
# 3  600077      10154      298-783-1774x6983        mmassey@example.org
# 4  600124      10282  001-602-572-7834x3940      nichole94@example.org
# 5  600054      10005       721-892-4705x758    daltonkiara@example.net
# 6  600045      10049       001-745-889-9694  chelseaprince@example.org
#
#          nomContact  qualite
# 0    Jeremy Vincent        2
# 1        Tina Potts        3
# 2  Cassandra Torres        2
# 3      Lucas Miller        1
# 4   Charles Sanders        1
# 5      Kayla Golden        2
# 6   Stephanie Davis        4
# [('600045', 10049, '001-745-889-9694', 'chelseaprince@example.org', 'Stephanie Davis', 4),
# ...

# %%
#Programme
programmedf = pd.DataFrame({'noProgramme': [1, 2,3,4], 'nom': ['Fidelio', 'Fidelio Or','Fidelio Platine','Fidelio Max'], 'cout':[15,25,60,100],'duree':[datetime(1,1,1),datetime(1,1,2),datetime(1,1,2),datetime(1,1,3)],'rabais':[5,8,10,12]})

engine.execute("DROP TABLE IF EXISTS programme;")
engine.execute("CREATE TABLE IF NOT EXISTS programme ( noProgramme INT PRIMARY KEY, nom VARCHAR(40), cout INT, duree dateTIME, rabais INT );")
print(programmedf)
programmedf.to_sql('programme', con=engine,if_exists='append',index=False)
engine.execute("SELECT * FROM programme").fetchall()
# Out:
#    noProgramme              nom  cout                duree  rabais
# 0            1          Fidelio    15  0001-01-01 00:00:00       5
# 1            2       Fidelio Or    25  0001-01-02 00:00:00       8
# 2            3  Fidelio Platine    60  0001-01-02 00:00:00      10
# 3            4      Fidelio Max   100  0001-01-03 00:00:00      12
# [(1, 'Fidelio', 15, datetime.datetime(1, 1, 1, 0, 0), 5),
#  (2, 'Fidelio Or', 25, datetime.datetime(1, 1, 2, 0, 0), 8),
#  (3, 'Fidelio Platine', 60, datetime.datetime(1, 1, 2, 0, 0), 10),
#  (4, 'Fidelio Max', 100, datetime.datetime(1, 1, 3, 0, 0), 12)]
